# %%
# %load_ext sql
# %sql mysql://root:92983574@localhost:3306/imdb
# %sql USE IMDB;
# Out:
# 0 rows affected.
# []

# %%
# %sql show tables
# Out:
# 6 rows affected.
# [('Actors',),
#  ('AudienceRating',),
#  ('CriticsRating',),
#  ('Directors',),
#  ('Movies',),
#  ('Rating',)]

# %%
# %sql select count(imdbID) from Movies
# Out:
# 1 rows affected.
# [(33042L,)]

# %%
result = %sql select imdbRating, count(*)*100/33000 as movie_num \
from Movies as m, Rating as r \
where m.imdbID = r.imdbID \
group by imdbRating
# Out:
# 91 rows affected.

# %%
result
# Out:
# [(1.0, Decimal('0.0485')),
#  (1.1, Decimal('0.0182')),
#  (1.2, Decimal('0.0303')),
#  (1.3, Decimal('0.0333')),
#  (1.4, Decimal('0.0303')),
#  (1.5, Decimal('0.0303')),
#  (1.6, Decimal('0.0424')),
#  (1.7, Decimal('0.0333')),
#  (1.8, Decimal('0.0545')),
#  (1.9, Decimal('0.0515')),
#  (2.0, Decimal('0.1000')),
#  (2.1, Decimal('0.0697')),
#  (2.2, Decimal('0.1455')),
#  (2.3, Decimal('0.0879')),
#  (2.4, Decimal('0.1212')),
#  (2.5, Decimal('0.1545')),
#  (2.6, Decimal('0.1273')),
#  (2.7, Decimal('0.1455')),
#  (2.8, Decimal('0.2152')),
#  (2.9, Decimal('0.1424')),
#  (3.0, Decimal('0.2939')),
#  (3.1, Decimal('0.2091')),
#  (3.2, Decimal('0.2788')),
#  (3.3, Decimal('0.2576')),
#  (3.4, Decimal('0.2606')),
#  (3.5, Decimal('0.3091')),
#  (3.6, Decimal('0.3273')),
#  (3.7, Decimal('0.3030')),
#  (3.8, Decimal('0.3909')),
#  (3.9, Decimal('0.3485')),
#  (4.0, Decimal('0.5364')),
#  (4.1, Decimal('0.4636')),
#  (4.2, Decimal('0.5818')),
#  (4.3, Decimal('0.6667')),
# ...

# %%
import pandas as pd
df = pd.DataFrame(result, columns=result.keys)
df
# Out:
#     imdbRating movie_num
# 0          1.0    0.0485
# 1          1.1    0.0182
# 2          1.2    0.0303
# 3          1.3    0.0333
# 4          1.4    0.0303
# 5          1.5    0.0303
# 6          1.6    0.0424
# 7          1.7    0.0333
# 8          1.8    0.0545
# 9          1.9    0.0515
# 10         2.0    0.1000
# 11         2.1    0.0697
# 12         2.2    0.1455
# 13         2.3    0.0879
# 14         2.4    0.1212
# 15         2.5    0.1545
# 16         2.6    0.1273
# 17         2.7    0.1455
# 18         2.8    0.2152
# 19         2.9    0.1424
# 20         3.0    0.2939
# 21         3.1    0.2091
# 22         3.2    0.2788
# 23         3.3    0.2576
# 24         3.4    0.2606
# 25         3.5    0.3091
# 26         3.6    0.3273
# 27         3.7    0.3030
# 28         3.8    0.3909
# 29         3.9    0.3485
# ..         ...       ...
# 61         7.1    2.9000
# 62         7.2    3.2273
# 63         7.3    3.3212
# 64         7.4    3.4242
# 65         7.5    2.7455
# ...

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
import numpy as np
xvalues = df['imdbRating']
yvalues = df['movie_num']
plt.plot(xvalues, yvalues, 'ro')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a01d0e0914d0> in <module>()
#       1 import numpy as np
# ----> 2 xvalues = df['imdbRating']
#       3 yvalues = df['movie_num']
#       4 plt.plot(xvalues, yvalues, 'ro')
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt

# %%
# %%sql
#
# select imdbRating, count(*) as movie_num
# from Movies as m, Rating as r
# where m.imdbID = r.imdbID
# group by imdbRating;
# Out:
# 91 rows affected.
# [(1.0, 16L),
#  (1.1, 6L),
#  (1.2, 10L),
#  (1.3, 11L),
#  (1.4, 10L),
#  (1.5, 10L),
#  (1.6, 14L),
#  (1.7, 11L),
#  (1.8, 18L),
#  (1.9, 17L),
#  (2.0, 33L),
#  (2.1, 23L),
#  (2.2, 48L),
#  (2.3, 29L),
#  (2.4, 40L),
#  (2.5, 51L),
#  (2.6, 42L),
#  (2.7, 48L),
#  (2.8, 71L),
#  (2.9, 47L),
#  (3.0, 97L),
#  (3.1, 69L),
#  (3.2, 92L),
#  (3.3, 85L),
#  (3.4, 86L),
#  (3.5, 102L),
#  (3.6, 108L),
#  (3.7, 100L),
#  (3.8, 129L),
#  (3.9, 115L),
#  (4.0, 177L),
#  (4.1, 153L),
#  (4.2, 192L),
#  (4.3, 220L),
#  (4.4, 211L),
#  (4.5, 185L),
#  (4.6, 257L),
#  (4.7, 260L),
#  (4.8, 307L),
#  (4.9, 264L),
#  (5.0, 318L),
#  (5.1, 322L),
#  (5.2, 395L),
#  (5.3, 416L),
#  (5.4, 461L),
#  (5.5, 473L),
#  (5.6, 593L),
#  (5.7, 537L),
#  (5.8, 665L),
#  (5.9, 583L),
#  (6.0, 762L),
#  (6.1, 720L),
#  (6.2, 795L),
#  (6.3, 936L),
#  (6.4, 918L),
#  (6.5, 853L),
#  (6.6, 999L),
#  (6.7, 854L),
#  (6.8, 1147L),
#  (6.9, 932L),
#  (7.0, 1109L),
#  (7.1, 957L),
# ...

# %%
result1 = %sql select userRating, count(*)*100/6658 as movie_num \
from AudienceRating \
where userRating >0 \
group by userRating
# Out:
# 45 rows affected.

# %%
df1 = pd.DataFrame(result1, columns=result1.keys)
df1
# Out:
#     userRating movie_num
# 0          0.5    0.8711
# 1          0.7    0.0300
# 2          0.8    0.1502
# 3          0.9    0.0451
# 4          1.0    1.1415
# 5          1.1    0.0601
# 6          1.2    0.3755
# 7          1.3    0.2103
# 8          1.4    0.1352
# 9          1.5    1.3217
# 10         1.6    0.3755
# 11         1.7    0.4055
# 12         1.8    1.1265
# 13         1.9    0.3605
# 14         2.0    2.7786
# 15         2.1    0.7209
# 16         2.2    1.8474
# 17         2.3    1.2466
# 18         2.4    1.3367
# 19         2.5    4.2355
# 20         2.6    1.4569
# 21         2.7    1.7423
# 22         2.8    2.9889
# 23         2.9    2.2980
# 24         3.0    6.9691
# 25         3.1    2.9739
# 26         3.2    4.7462
# 27         3.3    3.6648
# 28         3.4    3.3644
# 29         3.5    7.9904
# 30         3.6    3.3193
# 31         3.7    3.3043
# 32         3.8    4.5359
# 33         3.9    3.1241
# 34         4.0    7.0592
# 35         4.1    2.2679
# ...

# %%
result2 = %sql select count(*)*100/1491 as movie_num, rating  \
from CriticsRating as c \
where rating >0 \
group by rating

df2 = pd.DataFrame(result2, columns=result2.keys)
# Out:
# 76 rows affected.

# %%
df2
# Out:
#    movie_num  rating
# 0     0.0671     0.7
# 1     0.1341     1.4
# 2     0.0671     1.6
# 3     0.1341     2.0
# 4     0.0671     2.1
# 5     0.2012     2.4
# 6     0.5366     2.5
# 7     0.3353     2.6
# 8     0.0671     2.7
# 9     0.4024     2.8
# 10    0.2683     2.9
# 11    0.2683     3.0
# 12    0.3353     3.1
# 13    0.1341     3.2
# 14    0.6707     3.3
# 15    0.6036     3.4
# 16    0.5366     3.5
# 17    0.8048     3.6
# 18    0.1341     3.7
# 19    0.8719     3.8
# 20    0.4695     3.9
# 21    1.3414     4.0
# 22    0.6707     4.1
# 23    1.2072     4.2
# 24    0.7378     4.3
# 25    0.8719     4.4
# 26    0.6707     4.5
# 27    1.2743     4.6
# 28    1.4085     4.7
# 29    1.8779     4.8
# ..       ...     ...
# 46    2.6157     6.5
# 47    2.7498     6.6
# 48    2.5486     6.7
# 49    4.0912     6.8
# 50    2.4816     6.9
# 51    4.0912     7.0
# 52    2.9510     7.1
# 53    3.3535     7.2
# 54    2.3474     7.3
# 55    3.0181     7.4
# 56    2.3474     7.5
# ...

# %%
xvalues1 = df['imdbRating']
yvalues1 = df['movie_num']
xvalues2 = df1['userRating']
yvalues2 = df1['movie_num']
xvalues3 = df2['rating']
yvalues3 = df2['movie_num']
#df.groupby(['imdbRating','movie_num']).plot(kind='bar')
plt.bar(left = df['imdbRating'], height = df['movie_num'], width =0.1,  color="#6495ED", alpha=0.8)
plt.bar(left = df1['userRating'], height = df1['movie_num']/2, width =0.1,  color="green", alpha=0.5)
plt.bar(left = df2['rating'], height = df2['movie_num'] ,width = 0.1,  color="#F08080", alpha=0.8)
#df.bar(['movie_num'], ['imdbRating'])
#df2.plot(xvalues3, yvalues3, kind = 'bar')
#plt.plot(xvalues3, yvalues3, 'go')
# Out:
# <Container object of 76 artists>

# %%
plt.bar(left = df['imdbRating'], height = df['movie_num'], width =0.1,  color="#6495ED", alpha=1)
plt.xlabel('Rating')
plt.ylabel('Percentage')
plt.title('IMDB User Rating Distribution (Avg = 6.39)')

# %%
plt.bar(left = df1['userRating']*2, height = df1['movie_num'], width =0.2,  color="green", alpha=0.5)
plt.xlabel('Rating')
plt.ylabel('Percentage')
plt.title('Rotten Tomato User Rating Distribution (Avg = 5.92)')
# Out:
# KeyboardInterrupt

# %%
plt.xlabel('Rating')
plt.ylabel('Percentage')
plt.title('Rotten Tomato Critics Rating Distribution (Avg = 6.18)')

# %%
# %%sql select avg(rating)
# from CriticsRating
# Out:
# 1 rows affected.
# [(6.1840026773761725,)]

# %%
plt.bar(left = df['imdbRating'], height = df['movie_num'], width =0.1,  color="#6495ED", alpha=1)
plt.bar(left = df1['userRating']*2, height = df1['movie_num'], width =0.2,  color="green", alpha=0.1)
plt.bar(left = df2['rating'], height = df2['movie_num'] ,width = 0.1,  color="#F08080", alpha=0.6)
plt.xlabel('Rating')
plt.ylabel('Percentage')
plt.title('Rating Distribution')

# %%
result1.plot()

# %%
avg0 = %sql select avg(imdbRating) as imdb_Rating, avg(userRating)*2 as rt_Rating, avg(rating) as rt_CritcsRating \
from Rating r \
inner join Movies m on r.imdbID = m.imdbID \
inner join AudienceRating a on m.imdbID = a.imdbID \
inner join CriticsRating c on c.imdbID = a.imdbID
# Out:
# 1 rows affected.

# %%
avg0
# Out:
# [(6.390795947901595, 5.917134587554308, 6.18016304347826)]

# %%
avg1 = %sql select avg(imdbRating) as imdb_Rating, avg(userRating)*2 as rt_Rating, avg(rating) as rt_CritcsRating \
from Rating r \
inner join Movies m on r.imdbID = m.imdbID \
inner join AudienceRating a on m.imdbID = a.imdbID \
inner join CriticsRating c on c.imdbID = a.imdbID \
where awards regexp "won|win"
# Out:
# 1 rows affected.

# %%
avg1
# Out:
# [(6.742595978062152, 6.528519195612408, 6.701749271137022)]

# %%
avg2 = %sql select avg(imdbRating) as imdb_Rating, avg(userRating)*2 as rt_Rating, avg(rating) as rt_CritcsRating \
from Rating r \
inner join Movies m on r.imdbID = m.imdbID \
inner join AudienceRating a on m.imdbID = a.imdbID \
inner join CriticsRating c on c.imdbID = a.imdbID \
where awards regexp "nominated|nomination"
# Out:
# 1 rows affected.

# %%
avg2
# Out:
# [(6.6181400688863405, 6.415308075009585, 6.576732673267321)]

# %%
a = ['imdb_Rating', 'rt_Rating', 'rt_CritcsRating']
a11 = ('A', 'B', 'C')
a0 = [6.39, 5.92, 6.18]
a1 = [6.74, 6.53, 6.70]
a2 = [6.62, 6.42, 6.58]
plt.bar(a0, ('A', 'B', 'C'))
#plt.bar(a11, a1, width = 0.2)
#plt.xticks(('A', 'B', 'C'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-07fbd92f2ca0> in <module>()
#       4 a1 = [6.74, 6.53, 6.70]
#       5 a2 = [6.62, 6.42, 6.58]
# ----> 6 plt.bar(a0, ('A', 'B', 'C'))
#       7 #plt.bar(a11, a1, width = 0.2)
#       8 #plt.xticks(('A', 'B', 'C'))
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in bar(left, height, width, bottom, hold, **kwargs)
#    2381         ax.hold(hold)
#    2382     try:
# -> 2383         ret = ax.bar(left, height, width=width, bottom=bottom, **kwargs)
#    2384         draw_if_interactive()
#    2385     finally:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes.pyc in bar(self, left, height, width, bottom, **kwargs)
#    4899             r.get_path()._interpolation_steps = 100
#    4900             #print r.get_label(), label, 'label' in kwargs
# -> 4901             self.add_patch(r)
# ...
