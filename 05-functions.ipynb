# %% [markdown]
# Functions help extract out common code blocks.
#
# Let's define a function `print_greeting()`.

# %%
def print_greeting():
    print "Hi there, how are you?"
    print "Long time no see."

# %% [markdown]
# And call it:

# %%
print_greeting()
# Out:
# Hi there, how are you?
# Long time no see.

# %% [markdown]
# That's a bit impersonal.

# %%
def print_greeting(name):
    print "Hi there, {0}, how are you?".format(name)
    print "Long time no see."

# %%
print_greeting("Andreas")
# Out:
# Hi there, Andreas, how are you?
# Long time no see.

# %% [markdown]
# But we might not know their name.
#
# (And we just changed the interface of `print_greeting`!)

# %%
def print_greeting(name="my friend"):
    print "Hi there, {0}, how are you?".format(name)
    print "Long time no see."

# %%
print_greeting("Andreas")
print_greeting()
# Out:
# Hi there, Andreas, how are you?
# Long time no see.
# Hi there, my friend, how are you?
# Long time no see.

# %% [markdown]
# ----

# %% [markdown]
# Function parameters work like variables.
#
# So what does this do?

# %%
def my_func(my_list):
    my_list.append(5)
    
l = [1,2,3]
my_func(l)
print l
# Out:
# [1, 2, 3, 5]

# %% [markdown]
# Can be very surprising!
#
# Define a better function `my_func_2`:

# %%
def my_func_2(my_list):
    return my_list + [5]

# %%
l = [1,2,3]
l2 = my_func_2(l)
print l
print l2
# Out:
# [1, 2, 3]
# [1, 2, 3, 5]

# %% [markdown]
# ----
#
# **Exercise:**
#
# Write a function `my_sort` that sorts a list `l` by doing the following:
#
# * Pick the first element off the list. Call that `x`.
# * Make a list `smaller` with all elements in `l` $\le$ `x`
#
#   (except `x` itself)
# * Make a list `bigger` with all elements in `l` $>$ `x`
# * Use `my_sort` to sort `smaller` and `bigger`.
# * Return a new list consisting of `smaller`, `x`, and `bigger`.

# %%
def my_sort(l):
    return l

# %%
from random import randrange
mylist = [randrange(0, 100) for i in range(20)]

print my_sort(mylist)
# Out:
# [15, 30, 88, 46, 47, 81, 85, 5, 47, 29, 33, 61, 76, 71, 72, 94, 8, 2, 27, 24]
