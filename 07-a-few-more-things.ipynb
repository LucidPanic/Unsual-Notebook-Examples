# %% [markdown]
# Getting help:
#
# 1) Use TAB in IPython

# %%
a = [1,2,3]

# %% [markdown]
# 2) Using `pydoc` on the command line.

# %% [markdown]
# 3) Online at <http://docs.python.org>

# %% [markdown]
# ----

# %% [markdown]
# **A few things to look up in a quiet moment**

# %% [markdown]
# String formatting

# %%
"My name is {0} and I like {1}".format("Andreas", "hiking")
# Out:
# 'My name is Andreas and I like hiking'

# %% [markdown]
# ---
# Dictionaries

# %%
prices = {"Tesla K40": 5000, "GTX Titan":1400}
prices["Tesla K40"]
# Out:
# 5000

# %% [markdown]
# ----
# Division

# %%
3/2
# Out:
# 1

# %% [markdown]
# Oops.

# %%
3./2
# Out:
# 1.5

# %% [markdown]
# Better. But that's clearly insane. So:

# %%
from __future__ import division

# %%
3/2
# Out:
# 1.5
