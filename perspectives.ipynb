# %% [markdown]
# # Future perspectives

# %% [markdown]
# Coefficient representation:
#
# * Spatially variable
# * Tensor-valued
# * Externally-read data
#
# Other concerns:
#
# * Targeting PyClaw
# * Boundary conditions

# %% [markdown]
# http://github.com/ibvp/ibvp
