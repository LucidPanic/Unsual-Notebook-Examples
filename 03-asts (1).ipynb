# %%
from cgen import *

# %%
func = FunctionBody(
    FunctionDeclaration(Const(Pointer(Value("char", "greet"))), []),
    Block([Statement('return "hello world"')])
    )

# %%
print func
# Out:
# char const *greet()
# {
#   return "hello world";
# }
